# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:right;border-radius:5px 5px;">
# <i>Material curado y desarrollado por Hernán D. Merlino</i><br>
# <i>AutoML - 2023 Q3</i></p>
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:25px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>AutoML Clustering</strong></p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:right;border-radius:px 5px;">
# Toda la información presentada en este trabajo fue extraída de:<br>
# <a href="https://www.packtpub.com/product/automated-machine-learning/9781800567689" target=\"_blank\">Automated Machine Learning</a><br>
# <a href="https://www.packtpub.com/product/hands-on-automated-machine-learning/9781788629898" target=\"_blank\">Hands-On Automated Machine Learning</a>
# </p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Definición</strong><br>
# AutoML tiene como objetivo facilitar el proceso de creación de modelos de AA mediante la automatización de los pasos de uso común, como el preprocesamiento de funciones, la selección de modelos y el ajuste de hiperparámetros.
# </p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Ciclo de Vida del ML</strong></p>

# %% [markdown]
# ![ML model life cycle](./img/proc.png)

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Ecosistema AutoML</strong></p>

# %% [markdown]
# ![Ecosistema](./img/eco.png)

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>AutoML Componentes</strong></p>

# %% [markdown]
# * Automated feature preprocessing
# * Automated algorithm selection
# * Hyperparameter optimization

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Principales Librerias</strong></p>

# %% [markdown]
# #### [Featuretools](https://www.featuretools.com/)
# #### [Auto-sklearn](http://automl.github.io/auto-sklearn/stable/)
# #### [MLBox](http://mlbox.readthedocs.io/en/latest/)
# #### [Tree-Based Pipeline Optimization Tool (TPOT)](http://epistasislab.github.io/tpot/)
# #### [PyCaret](https://pycaret.org/)
# #### [Auto-Weka](github.com/automl/autoweka)
# #### [Microsoft Neural Network Intelligence (NNI)]( https://github.com/microsoft/nni/)
# #### [Uber's automated ML tool (Ludwin)]( https://github.com/uber/ludwig/)
# #### [AutoGluon](https://github.com/awslabs/autogluon/)
# #### [H2O AutoML](https://github.com/h2oai/h2o-3/)

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>

# %%
# from pycaret.datasets import get_data

# %% [markdown]
# * **ID**: ID of each client
# * **LIMIT_BAL**: Amount of given credit in NT dollars (includes individual and family/supplementary credit)
# * **SEX**: Gender (1=male, 2=female)
# * **EDUCATION**: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# * **MARRIAGE**: Marital status (1=married, 2=single, 3=others)
# * **AGE**: Age in years
# * **PAY_0 to PAY_6**: Repayment status by n months ago (PAY_0 = last month ... PAY_6 = 6 months ago) (Labels: -1=pay duly, 1=payment delay for one month, 2=payment delay for two months, ... 8=payment delay for eight months, 9=payment delay for nine months and above)
# * **BILL_AMT1 to BILL_AMT6**: Amount of bill statement by n months ago ( BILL_AMT1 = last_month .. BILL_AMT6 = 6 months ago)
# * **PAY_AMT1 to PAY_AMT6**: Amount of payment by n months ago ( BILL_AMT1 = last_month .. BILL_AMT6 = 6 months ago)
# * **default**: Default payment (1=yes, 0=no) Target Column

# %%
# dataset = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
# dataset.shape
# Out:
# (24000, 24)

# %%
# data = dataset.sample(frac=0.95, random_state=786).reset_index(drop=True)

# %%
# data_unseen = dataset.drop(data.index).reset_index(drop=True)

# %%
# print('Data for Modeling: ' + str(data.shape))
# print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (22800, 24)
# Unseen Data For Predictions: (1200, 24)

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>

# %%
import pandas as pd
from datetime import datetime

# %%
from pycaret.classification import *

# %%
data = pd.read_csv("../superstore_data.csv")

# %%
data['Dt_Customer'] = pd.to_datetime(data['Dt_Customer'])

# %%
hoy = datetime.now()
data['TimeClient'] = (hoy - data['Dt_Customer']).dt.days

# %%
data = data.drop('Dt_Customer', axis=1)

# %%
data.rename(columns={'Response': 'target'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Recency              2240 non-null   int64
#  8   MntWines             2240 non-null   int64
#  9   MntFruits            2240 non-null   int64
#  10  MntMeatProducts      2240 non-null   int64
#  11  MntFishProducts      2240 non-null   int64
#  12  MntSweetProducts     2240 non-null   int64
#  13  MntGoldProds         2240 non-null   int64
#  14  NumDealsPurchases    2240 non-null   int64
# ...

# %%
exp_clf101 = setup(data = data, target = 'target', session_id=10001)
# Out:
# <style type="text/css">
# #T_8ea97_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8ea97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ea97_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8ea97_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ea97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ea97_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8ea97_row0_col1" class="data row0 col1" >10001</td>
#     </tr>
#     <tr>
#       <th id="T_8ea97_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8ea97_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8ea97_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_8ea97_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# * **session_id** : A pseudo-random number distributed as a seed in all functions for later reproducibility. If no session_id is passed, a random number is automatically generated that is distributed to all functions. In this experiment, the session_id is set as 123 for later reproducibility.
#
# * **Target Type** : Binary or Multiclass. The Target type is automatically detected and shown. There is no difference in how the experiment is performed for Binary or Multiclass problems. All functionalities are identical.
#
# * **Label Encoded** : When the Target variable is of type string (i.e. 'Yes' or 'No') instead of 1 or 0, it automatically encodes the label into 1 and 0 and displays the mapping (0 : No, 1 : Yes) for reference. In this experiment no label encoding is required since the target variable is of type numeric.
#
# * **Original Data** : Displays the original shape of the dataset. In this experiment (22800, 24) means 22,800 samples and 24 features including the target column.
#
# * **Missing Values** : When there are missing values in the original data this will show as True. For this experiment there are no missing values in the dataset.
#
# * **Numeric Features** : The number of features inferred as numeric. In this dataset, 14 out of 24 features are inferred as numeric.
#
# * **Categorical Features** : The number of features inferred as categorical. In this dataset, 9 out of 24 features are inferred as categorical.
#
# * **Transformed Train Set** : Displays the shape of the transformed training set. Notice that the original shape of (22800, 24) is transformed into (15959, 91) for the transformed train set and the number of features have increased to 91 from 24 due to categorical encoding
#
# * **Transformed Test Set** : Displays the shape of the transformed test/hold-out set. There are 6841 samples in test/hold-out set. This split is based on the default value of 70/30 that can be changed using the train_size parameter in setup.

# %%
best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             09:29:52
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_ac483 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# #### [The ultimate guide to binary classification metrics](https://towardsdatascience.com/the-ultimate-guide-to-binary-classification-metrics-c25c3627dd0a)

# %% [markdown]
# #### [24 Evaluation Metrics for Binary Classification ](https://neptune.ai/blog/evaluation-metrics-binary-classification)

# %% [markdown]
# #### [Precision, Recall, F1, Accuracy en clasificación](https://www.iartificial.net/precision-recall-f1-accuracy-en-clasificacion/)

# %% [markdown]
# #### [F1 Score vs ROC AUC vs Accuracy vs PR AUC](https://neptune.ai/blog/f1-score-accuracy-roc-auc-pr-auc)

# %% [markdown]
# #### [The advantages of the Matthews correlation coefficient (MCC) over F1 score and accuracy in binary classification evaluation](https://bmcgenomics.biomedcentral.com/articles/10.1186/s12864-019-6413-7)

# %%
print(best_model)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=10001, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
gbc = create_model('gbc')
# Out:
# <style type="text/css">
# #T_f06d0_row10_col0, #T_f06d0_row10_col1, #T_f06d0_row10_col2, #T_f06d0_row10_col3, #T_f06d0_row10_col4, #T_f06d0_row10_col5, #T_f06d0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f06d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f06d0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f06d0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f06d0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f06d0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f06d0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f06d0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f06d0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(gbc)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=10001, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Decision Tree Classifier</strong></p>

# %%
lightgbm = create_model('lightgbm')
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         09:44:05
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_a0b0a_row10_col0, #T_a0b0a_row10_col1, #T_a0b0a_row10_col2, #T_a0b0a_row10_col3, #T_a0b0a_row10_col4, #T_a0b0a_row10_col5, #T_a0b0a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a0b0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0b0a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a0b0a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a0b0a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a0b0a_level0_col3" class="col_heading level0 col3" >Prec.</th>
# ...

# %%
print(lightgbm)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=10001, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Neighbors Classifier</strong></p>

# %%
rf = create_model('rf')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  09:46:19
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
# <style type="text/css">
# #T_6f1b2_row10_col0, #T_6f1b2_row10_col1, #T_6f1b2_row10_col2, #T_6f1b2_row10_col3, #T_6f1b2_row10_col4, #T_6f1b2_row10_col5, #T_6f1b2_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6f1b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f1b2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6f1b2_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6f1b2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6f1b2_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6f1b2_level0_col4" class="col_heading level0 col4" >F1</th>
# ...

# %%
print(rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=10001, verbose=0, warm_start=False)

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Random Forest Classifier</strong></p>

# %%
nb = create_model('nb')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          09:46:48
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
# <style type="text/css">
# #T_1158a_row10_col0, #T_1158a_row10_col1, #T_1158a_row10_col2, #T_1158a_row10_col3, #T_1158a_row10_col4, #T_1158a_row10_col5, #T_1158a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1158a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1158a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1158a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1158a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1158a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1158a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1158a_level0_col5" class="col_heading level0 col5" >Kappa</th>
# ...

# %%
print(nb)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
xgboost = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_00843_row10_col0, #T_00843_row10_col1, #T_00843_row10_col2, #T_00843_row10_col3, #T_00843_row10_col4, #T_00843_row10_col5, #T_00843_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_00843">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00843_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_00843_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_00843_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_00843_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_00843_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_00843_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_00843_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print('xgboost')
# Out:
# xgboost

# %% [markdown]
# # FIN

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Tune a Model</strong></p>

# %%
tgbc = tune_model(gbc, optimize= 'Recall')
# Out:
# <style type="text/css">
# #T_815bb_row10_col0, #T_815bb_row10_col1, #T_815bb_row10_col2, #T_815bb_row10_col3, #T_815bb_row10_col4, #T_815bb_row10_col5, #T_815bb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_815bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_815bb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_815bb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_815bb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_815bb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_815bb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_815bb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_815bb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(tgbc, plot = 'auc')

# %%
plot_model(tgbc, plot = 'pr')

# %%
plot_model(tgbc, plot='feature')

# %%
plot_model(tgbc, plot = 'confusion_matrix')

# %%
evaluate_model(tgbc)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
print(tgbc)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.5, loss='log_loss', max_depth=4,
#                            max_features='log2', max_leaf_nodes=None,
#                            min_impurity_decrease=0.0005, min_samples_leaf=4,
#                            min_samples_split=9, min_weight_fraction_leaf=0.0,
#                            n_estimators=180, n_iter_no_change=None,
#                            random_state=10001, subsample=0.8, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
tlightgbm = tune_model(lightgbm, optimize= 'Recall')
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         12:06:53
# Status                Loading Dependencies
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_02d40_row10_col0, #T_02d40_row10_col1, #T_02d40_row10_col2, #T_02d40_row10_col3, #T_02d40_row10_col4, #T_02d40_row10_col5, #T_02d40_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_02d40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02d40_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_02d40_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_02d40_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_02d40_level0_col3" class="col_heading level0 col3" >Prec.</th>
# ...

# %%
plot_model(tlightgbm, plot = 'confusion_matrix')

# %%
print(tlightgbm)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=10001, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
trf = tune_model(rf, optimize= 'Recall')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   12:13:59
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .   Random Forest Classifier
# <style type="text/css">
# #T_bf520_row10_col0, #T_bf520_row10_col1, #T_bf520_row10_col2, #T_bf520_row10_col3, #T_bf520_row10_col4, #T_bf520_row10_col5, #T_bf520_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bf520">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf520_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bf520_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bf520_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bf520_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bf520_level0_col4" class="col_heading level0 col4" >F1</th>
# ...

# %%
plot_model(trf, plot = 'confusion_matrix')

# %%
print(trf)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='entropy', max_depth=6, max_features=1.0,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.5, min_samples_leaf=5,
#                        min_samples_split=5, min_weight_fraction_leaf=0.0,
#                        n_estimators=120, n_jobs=-1, oob_score=False,
#                        random_state=10001, verbose=0, warm_start=False)

# %%
tnb = tune_model(nb, optimize= 'Recall')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   12:21:48
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .                Naive Bayes
# <style type="text/css">
# #T_b819c_row10_col0, #T_b819c_row10_col1, #T_b819c_row10_col2, #T_b819c_row10_col3, #T_b819c_row10_col4, #T_b819c_row10_col5, #T_b819c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b819c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b819c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b819c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b819c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b819c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b819c_level0_col4" class="col_heading level0 col4" >F1</th>
# ...

# %%
plot_model(tnb, plot = 'confusion_matrix')

# %%
print(tnb)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
txgboost = tune_model(xgboost, optimize= 'Recall')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   12:28:31
# Status     . . . . . . . . . . . . . . . . . .       Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .  Extreme Gradient Boosting
# <style type="text/css">
# #T_a6d9a_row10_col0, #T_a6d9a_row10_col1, #T_a6d9a_row10_col2, #T_a6d9a_row10_col3, #T_a6d9a_row10_col4, #T_a6d9a_row10_col5, #T_a6d9a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a6d9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6d9a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a6d9a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a6d9a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a6d9a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a6d9a_level0_col4" class="col_heading level0 col4" >F1</th>
# ...

# %%
plot_model(txgboost, plot = 'confusion_matrix')

# %%
print(txgboost)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.15, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=2, missing=nan, monotone_constraints=None,
#               n_estimators=300, n_jobs=-1, num_parallel_tree=None,
#               objective='binary:logistic', predictor=None, ...)

# %% [markdown]
# # IGNORAR

# %%
import numpy as np
tuned_knn = tune_model(knn, custom_grid = {'n_neighbors' : np.arange(0,50,1)})
# Out:
# <style  type="text/css" >
#     #T_48971f40_01fb_11ec_b5fe_80c5f20e49e9row10_col0 {
#             background:  yellow;
#         }    #T_48971f40_01fb_11ec_b5fe_80c5f20e49e9row10_col1 {
#             background:  yellow;
#         }    #T_48971f40_01fb_11ec_b5fe_80c5f20e49e9row10_col2 {
#             background:  yellow;
#         }    #T_48971f40_01fb_11ec_b5fe_80c5f20e49e9row10_col3 {
#             background:  yellow;
#         }    #T_48971f40_01fb_11ec_b5fe_80c5f20e49e9row10_col4 {
#             background:  yellow;
#         }    #T_48971f40_01fb_11ec_b5fe_80c5f20e49e9row10_col5 {
#             background:  yellow;
#         }    #T_48971f40_01fb_11ec_b5fe_80c5f20e49e9row10_col6 {
#             background:  yellow;
# ...

# %%
print(knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
print(tuned_knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=46, p=2,
#                      weights='uniform')

# %%
tuned_rf = tune_model(rf)
# Out:
# <style  type="text/css" >
#     #T_28365809_01fc_11ec_9025_80c5f20e49e9row10_col0 {
#             background:  yellow;
#         }    #T_28365809_01fc_11ec_9025_80c5f20e49e9row10_col1 {
#             background:  yellow;
#         }    #T_28365809_01fc_11ec_9025_80c5f20e49e9row10_col2 {
#             background:  yellow;
#         }    #T_28365809_01fc_11ec_9025_80c5f20e49e9row10_col3 {
#             background:  yellow;
#         }    #T_28365809_01fc_11ec_9025_80c5f20e49e9row10_col4 {
#             background:  yellow;
#         }    #T_28365809_01fc_11ec_9025_80c5f20e49e9row10_col5 {
#             background:  yellow;
#         }    #T_28365809_01fc_11ec_9025_80c5f20e49e9row10_col6 {
#             background:  yellow;
# ...

# %%
print(rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=10001,
#                        verbose=0, warm_start=False)

# %%
print(tuned_rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight={},
#                        criterion='entropy', max_depth=6, max_features=1.0,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=9,
#                        min_weight_fraction_leaf=0.0, n_estimators=240,
#                        n_jobs=-1, oob_score=False, random_state=10001,
#                        verbose=0, warm_start=False)

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Plot a Model</strong></p>

# %% [markdown]
# # FIN IGNORAR

# %% [markdown]
# #### AUC Plot

# %%
plot_model(tuned_rf, plot = 'auc')

# %% [markdown]
# #### Precision-Recall Curve

# %%
plot_model(tuned_rf, plot = 'pr')

# %% [markdown]
# #### Feature Importance Plot

# %%
plot_model(tuned_rf, plot='feature')

# %% [markdown]
# #### Confusion Matrix

# %%
plot_model(tuned_rf, plot = 'confusion_matrix')

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Predict on test

# %%
predict_model(tuned_rf)
# Out:
# <style  type="text/css" >
# </style><table id="T_44095ca9_01fc_11ec_bd28_80c5f20e49e9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_44095ca9_01fc_11ec_bd28_80c5f20e49e9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_44095ca9_01fc_11ec_bd28_80c5f20e49e9row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Finalize Model</strong></p>

# %%
final_rf = finalize_model(tuned_rf)

# %%
print(final_rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight={},
#                        criterion='entropy', max_depth=6, max_features=1.0,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=9,
#                        min_weight_fraction_leaf=0.0, n_estimators=240,
#                        n_jobs=-1, oob_score=False, random_state=10001,
#                        verbose=0, warm_start=False)

# %%
predict_model(final_rf)
# Out:
# <style  type="text/css" >
# </style><table id="T_9587c75c_01fc_11ec_bffe_80c5f20e49e9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9587c75c_01fc_11ec_bffe_80c5f20e49e9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9587c75c_01fc_11ec_bffe_80c5f20e49e9row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...

# %%
unseen_predictions = predict_model(final_rf, data=data_unseen)
unseen_predictions.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      50000    2          2         1   48      0      0      0      0
# 1     200000    2          1         1   40      2      2      2      2
# 2      50000    2          3         1   44      1      2      3      2
# 3      60000    2          2         1   31      2      2     -1      0
# 4     120000    2          3         2   32     -1      0      0      0
#
#    PAY_5  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0      0  ...     8011.0    2028.0    2453.0    2329.0     431.0     300.0
# 1      2  ...    89112.0    4200.0    4100.0    3000.0    3400.0    3500.0
# 2      4  ...    15798.0    2100.0    1000.0    2300.0       0.0       0.0
# 3      0  ...    30384.0    1132.0   60994.0    1436.0    1047.0    1056.0
# 4      0  ...    81354.0    2429.0    3120.0    3300.0   10000.0    3200.0
#
#    PAY_AMT6  default  Label   Score
# 0     500.0        0      0  0.8545
# ...

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Predict on unseen data</strong></p>

# %%
from pycaret.utils import check_metric
check_metric(unseen_predictions['default'], unseen_predictions['Label'], metric = 'Accuracy')
# Out:
# 0.8275

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:20px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>Saving/Loading Model</strong></p>

# %%
save_model(final_rf,'./model/Final RF Model')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='default',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight={}, criterion='entropy',
# ...

# %%
saved_final_rf = load_model('./model/Final RF Model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(saved_final_rf, data=data_unseen)

# %%
new_prediction.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      50000    2          2         1   48      0      0      0      0
# 1     200000    2          1         1   40      2      2      2      2
# 2      50000    2          3         1   44      1      2      3      2
# 3      60000    2          2         1   31      2      2     -1      0
# 4     120000    2          3         2   32     -1      0      0      0
#
#    PAY_5  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0      0  ...     8011.0    2028.0    2453.0    2329.0     431.0     300.0
# 1      2  ...    89112.0    4200.0    4100.0    3000.0    3400.0    3500.0
# 2      4  ...    15798.0    2100.0    1000.0    2300.0       0.0       0.0
# 3      0  ...    30384.0    1132.0   60994.0    1436.0    1047.0    1056.0
# 4      0  ...    81354.0    2429.0    3120.0    3300.0   10000.0    3200.0
#
#    PAY_AMT6  default  Label   Score
# 0     500.0        0      0  0.8545
# ...

# %% [markdown]
# #### results of unseen_predictions and new_prediction are identical

# %%
from pycaret.utils import check_metric
check_metric(new_prediction['default'], new_prediction['Label'], metric = 'Accuracy')
# Out:
# 0.8275

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>
